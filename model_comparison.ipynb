# %%
import os
import pandas as pd
import numpy as np

# %%
# General definitions
PRECISION = "precision"
RECALL = "recall"
F1SCORE = "f1-score"
SUPPORT = "support"
METRICS = [PRECISION, RECALL, F1SCORE, SUPPORT]

model_results = r".\model_results"
csv_model_result_file_name = "model_results.csv"

# %% [markdown]
# ### Loading the model results and preparing them for visualization

# %%
merged_dataframes = {PRECISION: pd.DataFrame(), RECALL: pd.DataFrame(), F1SCORE: pd.DataFrame(),
                     SUPPORT: pd.DataFrame()
                     }
# Loop through all the models, folder structure and file name have to be as expected
for model, _, _ in os.walk(model_results):
    if model != model_results:  # Just ignore the root folder
        current_model_string = model.split('\\')[-1]
        # read dataframe and append model suffix to the columns, makes them unique for the later merge
        res = pd.read_csv(os.path.join(model, csv_model_result_file_name), sep=";")
        res.columns = [str(col) + current_model_string[-2:] if idx != 0 else col for idx, col in
                       enumerate(res.columns)]
        # Loop through the different metrics and create a merge dataframe for each one
        for metric in METRICS:
            # Get corresponding container
            df = merged_dataframes[metric]
            # Cut only precision part
            res_reduced = res[["Unnamed: 0", metric + current_model_string[-2:]]]
            if df.size == 0:
                df = res_reduced
            else:
                df = df.merge(res_reduced, how='right')
            previous_model_string = current_model_string
            merged_dataframes[metric] = df

# %% [markdown]
# We have now 4 dataframes, one for each metric, and we can easily highlight which model performs best for which metric

# %% [markdown]
# ### Lets start with defining our own custom highlighting function, for Series, and some cleaning up functions

# %%
# Very largely based on the example from the panda's doc
def highlight_max(data, color='yellow'):
    attr = 'background-color: {}'.format(color)
    if data.ndim == 1:  # Series from .apply(axis=0) or axis=1
        is_max = data == data.max()
        return [attr if v else '' for v in is_max]

# %%
def apply_highlighting(df):
    return df.style.apply(highlight_max, color='lightgreen', axis=1)

# %%
def reduce_dataframe(df):
    """ Removes the extra entries that do not correspond to categories, as well as reports
    the number of categories for which all models fail to perform and removes these 
    categories also from the reduced dataframe """
    # Set the index column for conveniancy
    df = df.set_index("Unnamed: 0")
    # Drop undesired rows
    df.drop(index=['micro avg', 'macro avg', 'weighted avg', 'samples avg'], inplace=True)
    # Find out how many categories are blank for all models
    only_zeroes = (df.T == 0).any().sum()
    print("%d categories have zeros for all models!" % only_zeroes)
    # Clean up and return dataframe
    return df #df[(df.T != 0).any()]

# %% [markdown]
# ### Lets checkout which models performs the best, metric per metric

# %% [markdown]
# #### Precision

# %%
precision_df = reduce_dataframe(merged_dataframes[PRECISION])
apply_highlighting(precision_df)
# Out:
# 14 categories have zeros for all models!
# <style  type="text/css" >
#     #T_7bb43964_745f_11eb_b194_e86f389933c2row0_col2 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row1_col0 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row2_col0 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row2_col1 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row2_col2 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row3_col0 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row4_col2 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row5_col1 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row6_col1 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row7_col0 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row8_col2 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row9_col0 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row9_col1 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row9_col2 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row10_col1 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row11_col1 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row12_col0 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row13_col1 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row14_col1 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row15_col2 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row16_col0 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row16_col1 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row17_col0 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row18_col1 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row19_col0 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row19_col1 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row19_col2 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row20_col0 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row21_col2 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row22_col0 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row22_col1 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row23_col0 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row23_col1 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row23_col2 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row24_col0 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row24_col1 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row24_col2 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row25_col0 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row25_col1 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row25_col2 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row26_col0 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row26_col1 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row26_col2 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row27_col2 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row28_col0 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row29_col1 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row30_col2 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row31_col0 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row31_col1 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row31_col2 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row32_col1 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row33_col2 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row34_col2 {
#             background-color:  lightgreen;
#         }    #T_7bb43964_745f_11eb_b194_e86f389933c2row35_col0 {
#             background-color:  lightgreen;
#         }</style><table id="T_7bb43964_745f_11eb_b194_e86f389933c2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >precision_a</th>        <th class="col_heading level0 col1" >precision_b</th>        <th class="col_heading level0 col2" >precision_c</th>    </tr>    <tr>        <th class="index_name level0" >Unnamed: 0</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7bb43964_745f_11eb_b194_e86f389933c2level0_row0" class="row_heading level0 row0" >related</th>
#                         <td id="T_7bb43964_745f_11eb_b194_e86f389933c2row0_col0" class="data row0 col0" >0.831205</td>
#                         <td id="T_7bb43964_745f_11eb_b194_e86f389933c2row0_col1" class="data row0 col1" >0.825564</td>
#                         <td id="T_7bb43964_745f_11eb_b194_e86f389933c2row0_col2" class="data row0 col2" >0.845039</td>
#             </tr>
#             <tr>
#                         <th id="T_7bb43964_745f_11eb_b194_e86f389933c2level0_row1" class="row_heading level0 row1" >request</th>
#                         <td id="T_7bb43964_745f_11eb_b194_e86f389933c2row1_col0" class="data row1 col0" >0.884058</td>
#                         <td id="T_7bb43964_745f_11eb_b194_e86f389933c2row1_col1" class="data row1 col1" >0.879630</td>
#                         <td id="T_7bb43964_745f_11eb_b194_e86f389933c2row1_col2" class="data row1 col2" >0.868275</td>
#             </tr>
#             <tr>
#                         <th id="T_7bb43964_745f_11eb_b194_e86f389933c2level0_row2" class="row_heading level0 row2" >offer</th>
#                         <td id="T_7bb43964_745f_11eb_b194_e86f389933c2row2_col0" class="data row2 col0" >0.000000</td>
#                         <td id="T_7bb43964_745f_11eb_b194_e86f389933c2row2_col1" class="data row2 col1" >0.000000</td>
#                         <td id="T_7bb43964_745f_11eb_b194_e86f389933c2row2_col2" class="data row2 col2" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_7bb43964_745f_11eb_b194_e86f389933c2level0_row3" cl

# %% [markdown]
# #### Recall

# %%
recall_df = reduce_dataframe(merged_dataframes[RECALL])
apply_highlighting(recall_df)
# Out:
# 14 categories have zeros for all models!
# <style  type="text/css" >
#     #T_80a139fe_745f_11eb_b63d_e86f389933c2row0_col0 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row1_col2 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row2_col0 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row2_col1 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row2_col2 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row3_col2 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row4_col2 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row5_col2 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row6_col2 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row7_col0 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row8_col2 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row9_col0 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row9_col1 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row9_col2 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row10_col2 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row11_col2 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row12_col2 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row13_col2 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row14_col0 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row15_col2 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row16_col2 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row17_col2 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row18_col2 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row19_col0 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row19_col1 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row19_col2 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row20_col2 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row21_col2 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row22_col2 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row23_col0 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row23_col1 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row23_col2 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row24_col0 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row24_col1 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row24_col2 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row25_col0 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row25_col1 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row25_col2 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row26_col0 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row26_col1 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row26_col2 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row27_col2 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row28_col2 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row29_col2 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row30_col2 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row31_col0 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row31_col1 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row31_col2 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row32_col2 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row33_col2 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row34_col2 {
#             background-color:  lightgreen;
#         }    #T_80a139fe_745f_11eb_b63d_e86f389933c2row35_col2 {
#             background-color:  lightgreen;
#         }</style><table id="T_80a139fe_745f_11eb_b63d_e86f389933c2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >recall_a</th>        <th class="col_heading level0 col1" >recall_b</th>        <th class="col_heading level0 col2" >recall_c</th>    </tr>    <tr>        <th class="index_name level0" >Unnamed: 0</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_80a139fe_745f_11eb_b63d_e86f389933c2level0_row0" class="row_heading level0 row0" >related</th>
#                         <td id="T_80a139fe_745f_11eb_b63d_e86f389933c2row0_col0" class="data row0 col0" >0.959051</td>
#                         <td id="T_80a139fe_745f_11eb_b63d_e86f389933c2row0_col1" class="data row0 col1" >0.956147</td>
#                         <td id="T_80a139fe_745f_11eb_b63d_e86f389933c2row0_col2" class="data row0 col2" >0.946081</td>
#             </tr>
#             <tr>
#                         <th id="T_80a139fe_745f_11eb_b63d_e86f389933c2level0_row1" class="row_heading level0 row1" >request</th>
#                         <td id="T_80a139fe_745f_11eb_b63d_e86f389933c2row1_col0" class="data row1 col0" >0.420690</td>
#                         <td id="T_80a139fe_745f_11eb_b63d_e86f389933c2row1_col1" class="data row1 col1" >0.436280</td>
#                         <td id="T_80a139fe_745f_11eb_b63d_e86f389933c2row1_col2" class="data row1 col2" >0.487500</td>
#             </tr>
#             <tr>
#                         <th id="T_80a139fe_745f_11eb_b63d_e86f389933c2level0_row2" class="row_heading level0 row2" >offer</th>
#                         <td id="T_80a139fe_745f_11eb_b63d_e86f389933c2row2_col0" class="data row2 col0" >0.000000</td>
#                         <td id="T_80a139fe_745f_11eb_b63d_e86f389933c2row2_col1" class="data row2 col1" >0.000000</td>
#                         <td id="T_80a139fe_745f_11eb_b63d_e86f389933c2row2_col2" class="data row2 col2" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_80a139fe_745f_11eb_b63d_e86f389933c2level0_row3" class="row_heading level0 row3" >aid_related</th>
#                         <td id="T_80a139fe_745f_11eb_b63d_e86f389933c2row3_col0" class="data row3 col0" >0.490393</td>
#                         <td id="T_80a139fe_745f_11eb_b63d_

# %% [markdown]
# #### F1-score

# %%
f1score_df = reduce_dataframe(merged_dataframes[F1SCORE])
apply_highlighting(f1score_df)
# Out:
# 14 categories have zeros for all models!
# <style  type="text/css" >
#     #T_8507d6f6_745f_11eb_be54_e86f389933c2row0_col2 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row1_col2 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row2_col0 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row2_col1 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row2_col2 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row3_col2 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row4_col2 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row5_col2 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row6_col2 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row7_col0 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row8_col2 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row9_col0 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row9_col1 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row9_col2 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row10_col2 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row11_col2 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row12_col2 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row13_col2 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row14_col0 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row15_col2 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row16_col2 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row17_col2 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row18_col2 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row19_col0 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row19_col1 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row19_col2 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row20_col2 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row21_col2 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row22_col2 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row23_col0 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row23_col1 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row23_col2 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row24_col0 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row24_col1 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row24_col2 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row25_col0 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row25_col1 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row25_col2 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row26_col0 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row26_col1 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row26_col2 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row27_col2 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row28_col2 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row29_col2 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row30_col2 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row31_col0 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row31_col1 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row31_col2 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row32_col2 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row33_col2 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row34_col2 {
#             background-color:  lightgreen;
#         }    #T_8507d6f6_745f_11eb_be54_e86f389933c2row35_col2 {
#             background-color:  lightgreen;
#         }</style><table id="T_8507d6f6_745f_11eb_be54_e86f389933c2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >f1-score_a</th>        <th class="col_heading level0 col1" >f1-score_b</th>        <th class="col_heading level0 col2" >f1-score_c</th>    </tr>    <tr>        <th class="index_name level0" >Unnamed: 0</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8507d6f6_745f_11eb_be54_e86f389933c2level0_row0" class="row_heading level0 row0" >related</th>
#                         <td id="T_8507d6f6_745f_11eb_be54_e86f389933c2row0_col0" class="data row0 col0" >0.890563</td>
#                         <td id="T_8507d6f6_745f_11eb_be54_e86f389933c2row0_col1" class="data row0 col1" >0.886070</td>
#                         <td id="T_8507d6f6_745f_11eb_be54_e86f389933c2row0_col2" class="data row0 col2" >0.892710</td>
#             </tr>
#             <tr>
#                         <th id="T_8507d6f6_745f_11eb_be54_e86f389933c2level0_row1" class="row_heading level0 row1" >request</th>
#                         <td id="T_8507d6f6_745f_11eb_be54_e86f389933c2row1_col0" class="data row1 col0" >0.570093</td>
#                         <td id="T_8507d6f6_745f_11eb_be54_e86f389933c2row1_col1" class="data row1 col1" >0.583269</td>
#                         <td id="T_8507d6f6_745f_11eb_be54_e86f389933c2row1_col2" class="data row1 col2" >0.624416</td>
#             </tr>
#             <tr>
#                         <th id="T_8507d6f6_745f_11eb_be54_e86f389933c2level0_row2" class="row_heading level0 row2" >offer</th>
#                         <td id="T_8507d6f6_745f_11eb_be54_e86f389933c2row2_col0" class="data row2 col0" >0.000000</td>
#                         <td id="T_8507d6f6_745f_11eb_be54_e86f389933c2row2_col1" class="data row2 col1" >0.000000</td>
#                         <td id="T_8507d6f6_745f_11eb_be54_e86f389933c2row2_col2" class="data row2 col2" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_8507d6f6_745f_11eb_be54_e86f389933c2level0_row3" class="row_heading level0 row3" >aid_related</th>
#                         <td id="T_8507d6f6_745f_11eb_be54_e86f389933c2row3_col0" class="data row3 col0" >0.618580</td>
#                         <td id="T_8507d6f6_745f_11eb
